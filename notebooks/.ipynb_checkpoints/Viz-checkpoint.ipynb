# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tqdm
from functions import count_words
from functions import bar_words

# %%
df = pd.read_csv('../resources_unzipped/irish_headlines_clean.csv')

# %%
df.head()
# Out:
#    publish_date headline_category  \
# 0      19960102              news
# 1      19960102              news
# 2      19960102              news
# 3      19960102              news
# 4      19960102              news
#
#                                      headline_text  year  month  day  \
# 0         UUP sees possibility of voting Major out  1996      1    2
# 1   Pubs targeted as curbs on smoking are extended  1996      1    2
# 2  Papers reveal secret links with O'Neill cabinet  1996      1    2
# 3      Domestic chaos as Italy takes EU presidency  1996      1    2
# 4     Learning about the star to which we owe life  1996      1    2
#
#    headline_len category subcategory  \
# 0            40     news         NaN
# 1            46     news         NaN
# 2            47     news         NaN
# 3            43     news         NaN
# 4            44     news         NaN
#
#                            filtered_headlines
# 0           uup sees possibility voting major
# 1        pubs targeted curbs smoking extended
# 2  papers reveal secret links o'neill cabinet
# 3    domestic chaos italy takes eu presidency
# 4                      learning star owe life

# %%
df.groupby('category').count()['year'].sort_values(ascending = False).plot.bar()

# %%
df_subcategory_grouped_count = df.groupby('subcategory').count()['year'].head(20).sort_values(ascending=False).plot.bar()

# %%
year_article_counts = df.groupby('year').count()['day'].plot.bar()

# %%
df.groupby('month').count()['day'].plot.bar()

# %% [markdown]
# <h3> Plot of the number of articles for each month during the year. Each line represents a year.

# %%
year_month_grouped = df.groupby(['year', 'month']).count()

for year in range(1996, 2019):
    year_month_grouped.loc[year]['day'].plot.line()

plt.title('Number of articles per month (Each line is a year)')
# Out:
# Text(0.5, 1.0, 'Number of articles per month (Each line is a year)')

# %% [markdown]
# <h5> This shows the total articles by month allowing us to find which times had significant dips regarding the number of articles

# %%
year_month_grouped['day'].plot.line()
plt.title('Number of articles per month across all years')
# Out:
# Text(0.5, 1.0, 'Number of articles per month across all years')

# %%
year_month_grouped.loc[2000]['day'].plot.line()
plt.title('# of articles per month in 2000')
# Out:
# Text(0.5, 1.0, '# of articles per month in 2000')

# %%
year_month_grouped.loc[2010]['day'].plot.line()
plt.title('# of articles per month in 2010')
# Out:
# Text(0.5, 1.0, '# of articles per month in 2010')

# %%
df.head()
# Out:
#    publish_date headline_category  \
# 0      19960102              news
# 1      19960102              news
# 2      19960102              news
# 3      19960102              news
# 4      19960102              news
#
#                                      headline_text  year  month  day  \
# 0         UUP sees possibility of voting Major out  1996      1    2
# 1   Pubs targeted as curbs on smoking are extended  1996      1    2
# 2  Papers reveal secret links with O'Neill cabinet  1996      1    2
# 3      Domestic chaos as Italy takes EU presidency  1996      1    2
# 4     Learning about the star to which we owe life  1996      1    2
#
#    headline_len category subcategory  \
# 0            40     news         NaN
# 1            46     news         NaN
# 2            47     news         NaN
# 3            43     news         NaN
# 4            44     news         NaN
#
#                            filtered_headlines
# 0           uup sees possibility voting major
# 1        pubs targeted curbs smoking extended
# 2  papers reveal secret links o'neill cabinet
# 3    domestic chaos italy takes eu presidency
# 4                      learning star owe life

# %%
word_count_96 = count_words(df.loc[df['year'] == 1996]['filtered_headlines'])

# %%
bar_words(word_count_96, 20)

# %%
for year in range(1996, 2019):
    word_count = count_words(df.loc[df['year'] == year]['filtered_headlines'])
    bar_words(word_count)
    plt.xlabel('Number of Uses')
    plt.ylabel('Word')
    plt.title(f'Number of uses by word for {year}')
    plt.show()

# %%
years = range(1996, 2019)

# %%
year_total_word_count = {}

for year in years:
    year_total_word_count[year] = sum(list(count_words(df.loc[df['year'] == year]['filtered_headlines'], verbose = False).values()))
# Out:
#   File "<ipython-input-26-45732f1fab6a>", line 4
#     year_total_word_count[year] = sum(list(count_words(df.loc[df['year'] == year]['filtered_headlines'], verbose = False).values())
#                                                                                                                                    ^
# SyntaxError: unexpected EOF while parsing

# %%
sum(year_total_word_count.values())
# Out:
# 0
